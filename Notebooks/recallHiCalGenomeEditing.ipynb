# %% [markdown]
# ## Recall von HiCal auf genome_editing mithilfe von den Strategien: Titel, Zitate, Referenzen

# %% [markdown]
# Zusätzlich noch mit Stemming und Stopping auf dem Datensatz:Genome_editing

# %%
# %matplotlib nbagg
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import integrate
import numpy as np
def roundeffort(x):
    return 10*round(int(x)/10)
StandardNormal = pd.read_csv('/mnt/ceph/storage/data-tmp/2021/akpdk/AusgangslistenHiCal/genome_editing/Standard/Normal/output/bmi_42.avg.precisionrecall', delimiter=r"\s+")
StandardNormal['approach'] = 'HiCal'
StandardReferenzen = pd.read_csv('/mnt/ceph/storage/data-tmp/2021/akpdk/AusgangslistenHiCal/genome_editing/Standard/Referenzen/output/bmi_42.avg.precisionrecall', delimiter=r"\s+")
StandardReferenzen['approach'] = 'HiCal mit DeepCT(Referenzen)'
StandardReferenzenStemStop = pd.read_csv('/mnt/ceph/storage/data-tmp/2021/akpdk/AusgangslistenHiCal/genome_editing/Standard/ReferenzenStemStop/output/bmi_42.avg.precisionrecall', delimiter=r"\s+")
StandardReferenzenStemStop['approach'] = 'HiCal mit DeepCT(ReferenzenStemStop)'
StandardTitel = pd.read_csv('/mnt/ceph/storage/data-tmp/2021/akpdk/AusgangslistenHiCal/genome_editing/Standard/Titel/output/bmi_42.avg.precisionrecall', delimiter=r"\s+")
StandardTitel['approach'] = 'HiCal mit DeepCT(Titel)'
StandardTitelStemStop = pd.read_csv('/mnt/ceph/storage/data-tmp/2021/akpdk/AusgangslistenHiCal/genome_editing/Standard/TitelStemStop/output/bmi_42.avg.precisionrecall', delimiter=r"\s+")
StandardTitelStemStop['approach'] = 'HiCal mit DeepCT(TitelStemStop)'
StandardZitate = pd.read_csv('/mnt/ceph/storage/data-tmp/2021/akpdk/AusgangslistenHiCal/genome_editing/Standard/Zitate/output/bmi_42.avg.precisionrecall', delimiter=r"\s+")
StandardZitate['approach'] = 'HiCal mit DeepCT(Zitate)'
StandardZitateStemStop = pd.read_csv('/mnt/ceph/storage/data-tmp/2021/akpdk/AusgangslistenHiCal/genome_editing/Standard/ZitateStemStop/output/bmi_42.avg.precisionrecall', delimiter=r"\s+")
StandardZitateStemStop['approach'] = 'HiCal mit DeepCT(ZitateStemStop)'

# %%
df = pd.concat([StandardNormal,StandardReferenzen,StandardZitate,StandardTitel])
df['effort_rounded'] = df.effort.apply(lambda i: roundeffort(i))
sns.lineplot(data = df, x = 'effort_rounded', y = 'recall', hue = 'approach')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:xlabel='effort_rounded', ylabel='recall'>

# %%
df = pd.concat([StandardNormal,StandardReferenzenStemStop,StandardZitateStemStop,StandardTitelStemStop])
df['effort_rounded'] = df.effort.apply(lambda i: roundeffort(i))
sns.lineplot(data = df, x = 'effort_rounded', y = 'recall', hue = 'approach')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:xlabel='effort_rounded', ylabel='recall'>

# %% [markdown]
# ## Recall auf HiCal mit Volltext von den Strategien: Titel, Zitate, Referenzen

# %%
VolltextNormal = pd.read_csv('/mnt/ceph/storage/data-tmp/2021/akpdk/AusgangslistenHiCal/genome_editing/Volltext/Normal/output/bmi_42.avg.precisionrecall', delimiter=r"\s+")
VolltextNormal['approach'] = 'HiCal Volltext'
VolltextReferenzen = pd.read_csv('/mnt/ceph/storage/data-tmp/2021/akpdk/AusgangslistenHiCal/genome_editing/Volltext/Referenzen/output/bmi_42.avg.precisionrecall', delimiter=r"\s+")
VolltextReferenzen['approach'] = 'HiCal Volltext mit DeepCT(Referenzen)'
VolltextReferenzenStemStop = pd.read_csv('/mnt/ceph/storage/data-tmp/2021/akpdk/AusgangslistenHiCal/genome_editing/Volltext/ReferenzenStemStop/output/bmi_42.avg.precisionrecall', delimiter=r"\s+")
VolltextReferenzenStemStop['approach'] = 'HiCal Volltext mit DeepCT(ReferenzenStemStop)'
VolltextTitel = pd.read_csv('/mnt/ceph/storage/data-tmp/2021/akpdk/AusgangslistenHiCal/genome_editing/Volltext/Titel/output/bmi_42.avg.precisionrecall', delimiter=r"\s+")
VolltextTitel['approach'] = 'HiCal Volltext mit DeepCT(Titel)'
VolltextTitelStemStop = pd.read_csv('/mnt/ceph/storage/data-tmp/2021/akpdk/AusgangslistenHiCal/genome_editing/Volltext/TitelStemStop/output/bmi_42.avg.precisionrecall', delimiter=r"\s+")
VolltextTitelStemStop['approach'] = 'HiCal Volltext mit DeepCT(TitelStemStop)'
VolltextZitate = pd.read_csv('/mnt/ceph/storage/data-tmp/2021/akpdk/AusgangslistenHiCal/genome_editing/Volltext/Zitate/output/bmi_42.avg.precisionrecall', delimiter=r"\s+")
VolltextZitate['approach'] = 'HiCal Volltext mit DeepCT(Zitate)'
VolltextZitateStemStop = pd.read_csv('/mnt/ceph/storage/data-tmp/2021/akpdk/AusgangslistenHiCal/genome_editing/Volltext/ZitateStemStop/output/bmi_42.avg.precisionrecall', delimiter=r"\s+")
VolltextZitateStemStop['approach'] = 'HiCal Volltext mit DeepCT(ZitateStemStop)'

# %%
df = pd.concat([VolltextNormal,VolltextReferenzen,VolltextZitate,VolltextTitel])
df['effort_rounded'] = df.effort.apply(lambda i: roundeffort(i))
sns.lineplot(data = df, x = 'effort_rounded', y = 'recall', hue = 'approach')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:xlabel='effort_rounded', ylabel='recall'>

# %%
df = pd.concat([VolltextNormal,VolltextReferenzenStemStop,VolltextZitateStemStop,VolltextTitelStemStop])
df['effort_rounded'] = df.effort.apply(lambda i: roundeffort(i))
sns.lineplot(data = df, x = 'effort_rounded', y = 'recall', hue = 'approach')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:xlabel='effort_rounded', ylabel='recall'>
